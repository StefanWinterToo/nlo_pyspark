# %%
import pyspark
from pyspark.sql import DataFrame
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.sql.functions import *

# %%
def extract_bets(spark, debug = 0):
    df_bets = spark.read.parquet("../Case_1/bets_v1/part-00000-4ea82782-6afd-434c-8fee-42264167ffe1-c000.snappy.parquet")
    # Cast some fields
    #df_bets = df_bets.withColumn("legs.price.decimal", transform(df_bets["legs.price.decimal"], lambda x, i: (df_bets["legs.price.decimal"][i]).cast('float')))
    df_bets = df_bets.withColumn("account_id", col("account_id").cast('int'))
    df_bets = df_bets.withColumn("legs", transform(col("legs"), lambda x, i: x.price.withField("decimal", x.price.decimal.cast('float'))))
    
    if debug == 1:
        df_bets.show(truncate=0)
        df_bets.printSchema()
    
    return df_bets

# %%
def extract_trans(spark, debug = 0):
    df_trans = spark.read.parquet("../Case_1/trans_v1/part-00000-6d83da89-6ef2-4edc-8446-7838dce4bd1d-c000.snappy.parquet")    

    if debug == 1:
        df_trans.show(truncate=0)
        df_trans.printSchema()
    
    return df_trans

# %%
spark = SparkSession.builder.appName("case").getOrCreate()
extract_bets(spark, 1)
# Out:
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |sportsbook_id                       |account_id|legs                                                                                                                                                                                                                                                                                                                                                                                                                              |markets                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |4e781821-9bd5-43df-a886-55dd15614ea1|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {29, 50, 1.58, -173}, {3, 20, 1.15, -667}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}]                                                                                                                                         |[{35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |66ce7381-8a05-4aa3-aae5-c6bc65295a0c|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {14, 25, 1.56, -179}, {3, 20, 1.15, -667}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}, {22, 25, 1.88, -114}, {17, 25, 1.68, -148}, {49, 50, 1.98, -103}]                                                                       |[{35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35493209, 10304535, 224855, BASEBALL, |Philadelphia Phillies|, |MLB|, |United States|, |Money Line|, |Philadelphia Phillies| |v| |Detroit Tigers|, 2022-03-22T17:05:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35493489, 10304647, 224846, BASEBALL, |Pittsburgh Pirates|, |MLB|, |United States|, |Money Line|, |Pittsburgh Pirates| |v| |Baltimore Orioles|, 2022-03-22T17:05:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35383431, 10203944, 196077, FOOTBALL, |Melbourne Victory|, |Australia A-League|, |Australia|, |Match Result|, |Melbourne Victory| |v| |Western United FC|, 2022-03-23T08:05:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# |abda5fcf-9d5d-4534-954e-aacc42432725|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {14, 25, 1.56, -179}, {13, 100, 1.13, -770}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}, {22, 25, 1.88, -114}, {17, 25, 1.68, -148}, {49, 50, 1.98, -103}, {133, 100, 2.33, +133}, {33, 100, 1.33, -304}, {13, 25, 1.52, -193}]|[{35508011, 10307803, 196518, HANDBALL, |HSG Graz|, |Austria Handball Liga|, |Austria|, |Match Winner 3 Way|, |JAGS Voslau| |v| |HSG Graz|, 2022-03-23T18:30:00.000+0000}, {35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35526177, 10311900, 225616, FOOTBALL, |Union de Santa Fe|, |Argentina Cup|, |Argentina|, |Match Result|, |Union de Santa Fe| |v| |Sportivo Las Parejas|, 2022-03-23T22:10:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35493209, 10304535, 224855, BASEBALL, |Philadelphia Phillies|, |MLB|, |United States|, |Money Line|, |Philadelphia Phillies| |v| |Detroit Tigers|, 2022-03-22T17:05:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35493489, 10304647, 224846, BASEBALL, |Pittsburgh Pirates|, |MLB|, |United States|, |Money Line|, |Pittsburgh Pirates| |v| |Baltimore Orioles|, 2022-03-22T17:05:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35383431, 10203944, 196077, FOOTBALL, |Melbourne Victory|, |Australia A-League|, |Australia|, |Match Result|, |Melbourne Victory| |v| |Western United FC|, 2022-03-23T08:05:00.000+0000}, {35383343, 10203924, 196076, FOOTBALL, |Melbourne City FC|, |Australia A-League|, |Australia|, |Match Result|, |Brisbane Roar FC| |v| |Melbourne City FC|, 2022-03-23T08:35:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]|
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|114856230 |[{37, 50, 1.74, -136}]                                                                                                                                                                                                                                                                                                                                                                                                            |[{35644601, 10344031, 226772, FOOTBALL, |No|, |International Friendlies|, |World|, |Both Teams to Score|, |Montenegro| |v| |Greece|, 2022-03-28T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
#
# root
#  |-- sportsbook_id: string (nullable = true)
#  |-- account_id: integer (nullable = true)
#  |-- legs: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- num: integer (nullable = true)
#  |    |    |-- den: integer (nullable = true)
#  |    |    |-- decimal: float (nullable = true)
#  |    |    |-- americanOdds: string (nullable = true)
#  |-- markets: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- outcomeRef: string (nullable = true)
#  |    |    |-- marketRef: string (nullable = true)
#  |    |    |-- eventRef: string (nullable = true)
#  |    |    |-- categoryRef: string (nullable = true)
#  |    |    |-- outcomeName: string (nullable = true)
#  |    |    |-- eventTypeName: string (nullable = true)
#  |    |    |-- className: string (nullable = true)
#  |    |    |-- marketName: string (nullable = true)
#  |    |    |-- eventName: string (nullable = true)
#  |    |    |-- eventStartTime: string (nullable = true)
# DataFrame[sportsbook_id: string, account_id: int, legs: array<struct<num:int,den:int,decimal:float,americanOdds:string>>, markets: array<struct<outcomeRef:string,marketRef:string,eventRef:string,categoryRef:string,outcomeName:string,eventTypeName:string,className:string,marketName:string,eventName:string,eventStartTime:string>>]

# %%
extract_trans(spark, 1)
# Out:
# +------------------------------------+------------------------------------+---------+-----------------+---------+
# |sportsbook_id                       |trans_uuid                          |transType|config           |deltaCash|
# +------------------------------------+------------------------------------+---------+-----------------+---------+
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|07862be1-5c33-75ab-4b41-43d73e982405|ADJRESULT|Unsettlement_Lose|0.0      |
# |66ce7381-8a05-4aa3-aae5-c6bc65295a0c|125a6cc9-7de5-9cf8-15c2-e6cbfce633fd|RESULT   |Settlement_Lose  |0.0      |
# |abda5fcf-9d5d-4534-954e-aacc42432725|23cb5474-2337-ce1d-2400-53077e7909e1|RESULT   |Settlement_Lose  |0.0      |
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|65d2188b-a3ab-41e7-670d-c1bb89d673f6|WAGER    |SBOB_WAGER       |-0.34    |
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|68f7914a-17bb-9b5d-d677-c204ce045548|ADJRESULT|Resettlement_Win |0.7      |
# |66ce7381-8a05-4aa3-aae5-c6bc65295a0c|866205be-b9da-4887-49af-c081696505f3|WAGER    |SBOB_WAGER       |-0.26    |
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|8c418cbf-1b7a-503e-2fc6-8c0856a0b37c|RESULT   |Settlement_Lose  |0.0      |
# |4e781821-9bd5-43df-a886-55dd15614ea1|c62c05b8-a0df-fcd6-ab83-0050099dabdd|WAGER    |SBOB_WAGER       |-0.23    |
# |abda5fcf-9d5d-4534-954e-aacc42432725|d8144850-9565-a720-c439-b2194194063c|WAGER    |SBOB_WAGER       |-0.29    |
# |4e781821-9bd5-43df-a886-55dd15614ea1|f95f7afe-d9a0-6fa8-9996-b8823d5666a6|RESULT   |Settlement_Lose  |0.0      |
# +------------------------------------+------------------------------------+---------+-----------------+---------+
#
# root
#  |-- sportsbook_id: string (nullable = true)
#  |-- trans_uuid: string (nullable = true)
#  |-- transType: string (nullable = true)
#  |-- config: string (nullable = true)
#  |-- deltaCash: double (nullable = true)
# DataFrame[sportsbook_id: string, trans_uuid: string, transType: string, config: string, deltaCash: double]

# %% [markdown]
# In sportsbetting it's possible to bet on a combination of events. Information on these events can be found in table `bets_v1`. However per bet the source provides data in two separate arrays. The odds are received in a column called 'legs' and the type of bet and the name of the sports-event can be found in the 'markets' column. Your goal is to read `bets_v1` and add a column 'outcomes' which combines these two arrays, such that it becomes clear what are the odds for a specific market (i.e. a single list of outcomes in which all the information of an outcome is available).

# %%
bets_bronze = extract_bets(spark)

def add_outcomes_to_bets_bronze(df):
    df = df.withColumn("outcomes", transform(
    arrays_zip(col("legs"), col("markets")), lambda x: x
    ))
    return df

bets_bronze = add_outcomes_to_bets_bronze(bets_bronze)
bets_bronze.show()
# Out:
# +--------------------+----------+--------------------+--------------------+--------------------+
# |       sportsbook_id|account_id|                legs|             markets|            outcomes|
# +--------------------+----------+--------------------+--------------------+--------------------+
# |4e781821-9bd5-43d...| 112164134|[{7, 4, 2.75, +17...|[{35382838, 10203...|[{{7, 4, 2.75, +1...|
# |66ce7381-8a05-4aa...| 112164134|[{7, 4, 2.75, +17...|[{35382838, 10203...|[{{7, 4, 2.75, +1...|
# |abda5fcf-9d5d-453...| 112164134|[{7, 4, 2.75, +17...|[{35508011, 10307...|[{{7, 4, 2.75, +1...|
# |dcac73b6-18e4-4c9...| 114856230|[{37, 50, 1.74, -...|[{35644601, 10344...|[{{37, 50, 1.74, ...|
# +--------------------+----------+--------------------+--------------------+--------------------+

# %%
trans_bronze = extract_trans(spark)

def trans_transactions(df):
    df = df.groupBy(col("sportsbook_id")).agg(collect_list(struct( [col(column) for column in trans_bronze.columns if column != "sportsbook_id"] )).alias("transactions"))
    return df

trans_bronze = trans_transactions(trans_bronze)
trans_bronze.show()
# Out:
# +--------------------+--------------------+
# |       sportsbook_id|        transactions|
# +--------------------+--------------------+
# |abda5fcf-9d5d-453...|[{23cb5474-2337-c...|
# |dcac73b6-18e4-4c9...|[{07862be1-5c33-7...|
# |66ce7381-8a05-4aa...|[{125a6cc9-7de5-9...|
# |4e781821-9bd5-43d...|[{c62c05b8-a0df-f...|
# +--------------------+--------------------+

# %%
bets_silver = bets_bronze.join(trans_bronze, bets_bronze.sportsbook_id == trans_bronze.sportsbook_id, "left").drop(trans_bronze.sportsbook_id)
bets_silver.show(truncate=0)
# Out:
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------- ...
# |sportsbook_id                       |account_id|legs                                                                                                                                                                                                                                                                                                                                                                                                                              |markets                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          |outcomes                                                                                                   ...
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------- ...
# |4e781821-9bd5-43df-a886-55dd15614ea1|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {29, 50, 1.58, -173}, {3, 20, 1.15, -667}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}]                                                                                                                                         |[{35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |[{{7, 4, 2.75, +175}, {35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Sup ...
# |66ce7381-8a05-4aa3-aae5-c6bc65295a0c|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {14, 25, 1.56, -179}, {3, 20, 1.15, -667}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}, {22, 25, 1.88, -114}, {17, 25, 1.68, -148}, {49, 50, 1.98, -103}]                                                                       |[{35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35493209, 10304535, 224855, BASEBALL, |Philadelphia Phillies|, |MLB|, |United States|, |Money Line|, |Philadelphia Phillies| |v| |Detroit Tigers|, 2022-03-22T17:05:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35493489, 10304647, 224846, BASEBALL, |Pittsburgh Pirates|, |MLB|, |United States|, |Money Line|, |Pittsburgh Pirates| |v| |Baltimore Orioles|, 2022-03-22T17:05:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35383431, 10203944, 196077, FOOTBALL, |Melbourne Victory|, |Australia A-League|, |Australia|, |Match Result|, |Melbourne Victory| |v| |Western United FC|, 2022-03-23T08:05:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |[{{7, 4, 2.75, +175}, {35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Sup ...
# |abda5fcf-9d5d-4534-954e-aacc42432725|112164134 |[{7, 4, 2.75, +175}, {89, 100, 1.89, -113}, {131, 100, 2.31, +131}, {13, 50, 1.26, -385}, {11, 20, 1.55, -182}, {17, 10, 2.7, +170}, {14, 25, 1.56, -179}, {13, 100, 1.13, -770}, {21, 25, 1.84, -120}, {81, 100, 1.81, -124}, {2, 1, 3.0, +200}, {7, 4, 2.75, +175}, {37, 50, 1.74, -136}, {22, 25, 1.88, -114}, {17, 25, 1.68, -148}, {49, 50, 1.98, -103}, {133, 100, 2.33, +133}, {33, 100, 1.33, -304}, {13, 25, 1.52, -193}]|[{35508011, 10307803, 196518, HANDBALL, |HSG Graz|, |Austria Handball Liga|, |Austria|, |Match Winner 3 Way|, |JAGS Voslau| |v| |HSG Graz|, 2022-03-23T18:30:00.000+0000}, {35382838, 10203679, 196004, FOOTBALL, |Atletico Tucuman|, |Argentina Copa de la Superliga|, |Argentina|, |Match Result|, |Atletico Tucuman| |v| |CA Central Cordoba SE|, 2022-03-22T22:15:00.000+0000}, {35526177, 10311900, 225616, FOOTBALL, |Union de Santa Fe|, |Argentina Cup|, |Argentina|, |Match Result|, |Union de Santa Fe| |v| |Sportivo Las Parejas|, 2022-03-23T22:10:00.000+0000}, {35516061, 10309513, 225456, FOOTBALL, |Bramfelder SV|, |Germany Oberliga Hamburg|, |Germany|, |Match Result|, |Bramfelder SV| |v| |Union Tornesch|, 2022-03-22T18:00:00.000+0000}, {35525722, 10311734, 225609, FOOTBALL, |SV Spakenburg|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |SV Spakenburg| |v| |HHC Hardenberg|, 2022-03-22T19:00:00.000+0000}, {35495706, 10305340, 224950, BASKETBALL, |AS Monaco|, |Euroleague Men|, |European|, |Money Line|, |AS Monaco| |v| |BC Olympiakos Piraeus|, 2022-03-23T20:00:00.000+0000}, {35493209, 10304535, 224855, BASEBALL, |Philadelphia Phillies|, |MLB|, |United States|, |Money Line|, |Philadelphia Phillies| |v| |Detroit Tigers|, 2022-03-22T17:05:00.000+0000}, {35506845, 10307380, 225245, ICE_HOCKEY, |Karpat Oulu|, |Finland Liiga|, |Finland|, |Money Line|, |Karpat Oulu| |v| |KooKoo|, 2022-03-22T16:30:00.000+0000}, {35506801, 10307362, 225232, ICE_HOCKEY, |Tappara Tampere|, |Finland Liiga|, |Finland|, |Money Line|, |Tappara Tampere| |v| |Assat Pori|, 2022-03-22T16:30:00.000+0000}, {35493489, 10304647, 224846, BASEBALL, |Pittsburgh Pirates|, |MLB|, |United States|, |Money Line|, |Pittsburgh Pirates| |v| |Baltimore Orioles|, 2022-03-22T17:05:00.000+0000}, {35417234, 10209322, 196589, FOOTBALL, |SSV Ulm 1846|, |Germany Regionalliga Südwest|, |Germany|, |Match Result|, |SSV Ulm 1846| |v| |FC Astoria Walldorf|, 2022-03-22T18:00:00.000+0000}, {35487833, 10303766, 224919, FOOTBALL, |Kozakken Boys Werkendam|, |Netherlands Tweede Divisie|, Nederland, |Match Result|, |Kozakken Boys Werkendam| |v| |Amsterdamsche FC|, 2022-03-22T19:00:00.000+0000}, {35392901, 10205313, 196255, FOOTBALL, |Dunfermline Athletic FC|, |Scotland Championship|, |Scotland|, |Match Result|, |Dunfermline Athletic FC| |v| |Partick Thistle FC|, 2022-03-22T19:05:00.000+0000}, {35494103, 10304784, 224856, BASEBALL, |Minnesota Twins|, |MLB|, |United States|, |Money Line|, |Minnesota Twins| |v| |Atlanta Braves|, 2022-03-22T17:05:00.000+0000}, {35383431, 10203944, 196077, FOOTBALL, |Melbourne Victory|, |Australia A-League|, |Australia|, |Match Result|, |Melbourne Victory| |v| |Western United FC|, 2022-03-23T08:05:00.000+0000}, {35383343, 10203924, 196076, FOOTBALL, |Melbourne City FC|, |Australia A-League|, |Australia|, |Match Result|, |Brisbane Roar FC| |v| |Melbourne City FC|, 2022-03-23T08:35:00.000+0000}, {35518348, 10310093, 225495, BASKETBALL, |CB Murcia|, |Spanish ACB|, |Spain|, |Point Spread 2 Way| |-5.5|, |CB Murcia| |v| |CB Breogan|, 2022-03-23T19:30:00.000+0000}, {35516148, 10309553, 225468, FOOTBALL, |Sandnes Ulf|, |Club Friendlies|, |World|, |Match Result|, |Sandnes Ulf| |v| |Egersunds IK|, 2022-03-22T17:00:00.000+0000}, {35513498, 10308930, 225375, FOOTBALL, |TSV Bordesholm|, |Germany Oberliga Schleswig-Holstein|, |Germany|, |Match Result|, |TSV Bordesholm| |v| |TSV Altenholz|, 2022-03-22T18:00:00.000+0000}]|[{{7, 4, 2.75, +175}, {35508011, 10307803, 196518, HANDBALL, |HSG Graz|, |Austria Handball Liga|, |Austria ...
# |dcac73b6-18e4-4c9a-8900-9935e0e6b2fa|114856230 |[{37, 50, 1.74, -136}]                                                                                                                                                                                                                                                                                                                                                                                                            |[{35644601, 10344031, 226772, FOOTBALL, |No|, |International Friendlies|, |World|, |Both Teams to Score|, |Montenegro| |v| |Greece|, 2022-03-28T18:00:00.000+0000}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |[{{37, 50, 1.74, -136}, {35644601, 10344031, 226772, FOOTBALL, |No|, |International Friendlies|, |World|,  ...
# +------------------------------------+----------+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+---------------------------------------------------------------------------------------------------------- ...

# %%
bet_gold = bets_silver.select(["sportsbook_id", "account_id", "outcomes", "transactions"])
bet_gold.show()
# Out:
# +--------------------+----------+--------------------+--------------------+
# |       sportsbook_id|account_id|            outcomes|        transactions|
# +--------------------+----------+--------------------+--------------------+
# |4e781821-9bd5-43d...| 112164134|[{{7, 4, 2.75, +1...|[{c62c05b8-a0df-f...|
# |66ce7381-8a05-4aa...| 112164134|[{{7, 4, 2.75, +1...|[{125a6cc9-7de5-9...|
# |abda5fcf-9d5d-453...| 112164134|[{{7, 4, 2.75, +1...|[{23cb5474-2337-c...|
# |dcac73b6-18e4-4c9...| 114856230|[{{37, 50, 1.74, ...|[{07862be1-5c33-7...|
# +--------------------+----------+--------------------+--------------------+

# %%
import pyarrow.parquet as pq
pq.read_table('./Case_1/bets_interview_completed.parquet')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pyarrow.parquet as pq
# ----> 2 pq.read_table('./Case_1/bets_interview_completed.parquet')
#
# File c:\DEV\NLO_Case\nlo_case\Lib\site-packages\pyarrow\parquet\core.py:2939, in read_table(source, columns, use_threads, metadata, schema, use_pandas_metadata, read_dictionary, memory_map, buffer_size, partitioning, filesystem, filters, use_legacy_dataset, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#    2932     raise ValueError(
#    2933         "The 'metadata' keyword is no longer supported with the new "
#    2934         "datasets-based implementation. Specify "
#    2935         "'use_legacy_dataset=True' to temporarily recover the old "
#    2936         "behaviour."
#    2937     )
#    2938 try:
# -> 2939     dataset = _ParquetDatasetV2(
#    2940         source,
#    2941         schema=schema,
#    2942         filesystem=filesystem,
#    2943         partitioning=partitioning,
#    2944         memory_map=memory_map,
#    2945         read_dictionary=read_dictionary,
#    2946         buffer_size=buffer_size,
#    2947         filters=filters,
#    2948         ignore_prefixes=ignore_prefixes,
#    2949         pre_buffer=pre_buffer,
#    2950         coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#    2951         thrift_string_size_limit=thrift_string_size_limit,
#    2952         thrift_container_size_limit=thrift_container_size_limit,
#    2953     )
#    2954 except ImportError:
#    2955     # fall back on ParquetFile for simple cases when pyarrow.dataset
#    2956     # module is not available
#    2957     if filters is not None:
#
# File c:\DEV\NLO_Case\nlo_case\Lib\site-packages\pyarrow\parquet\core.py:2490, in _ParquetDatasetV2.__init__(self, path_or_paths, filesystem, filters, partitioning, read_dictionary, buffer_size, memory_map, ignore_prefixes, pre_buffer, coerce_int96_timestamp_unit, schema, decryption_properties, thrift_string_size_limit, thrift_container_size_limit, **kwargs)
#    2486 if partitioning == "hive":
#    2487     partitioning = ds.HivePartitioning.discover(
#    2488         infer_dictionary=True)
# -> 2490 self._dataset = ds.dataset(path_or_paths, filesystem=filesystem,
#    2491                            schema=schema, format=parquet_format,
#    2492                            partitioning=partitioning,
#    2493                            ignore_prefixes=ignore_prefixes)
#
# File c:\DEV\NLO_Case\nlo_case\Lib\site-packages\pyarrow\dataset.py:763, in dataset(source, schema, format, filesystem, partitioning, partition_base_dir, exclude_invalid_files, ignore_prefixes)
#     752 kwargs = dict(
#     753     schema=schema,
#     754     filesystem=filesystem,
#    (...)
#     759     selector_ignore_prefixes=ignore_prefixes
#     760 )
#     762 if _is_path_like(source):
# --> 763     return _filesystem_dataset(source, **kwargs)
#     764 elif isinstance(source, (tuple, list)):
#     765     if all(_is_path_like(elem) for elem in source):
#
# File c:\DEV\NLO_Case\nlo_case\Lib\site-packages\pyarrow\dataset.py:446, in _filesystem_dataset(source, schema, filesystem, partitioning, format, partition_base_dir, exclude_invalid_files, selector_ignore_prefixes)
#     444     fs, paths_or_selector = _ensure_multiple_sources(source, filesystem)
#     445 else:
# --> 446     fs, paths_or_selector = _ensure_single_source(source, filesystem)
#     448 options = FileSystemFactoryOptions(
#     449     partitioning=partitioning,
#     450     partition_base_dir=partition_base_dir,
#     451     exclude_invalid_files=exclude_invalid_files,
#     452     selector_ignore_prefixes=selector_ignore_prefixes
#     453 )
#     454 factory = FileSystemDatasetFactory(fs, paths_or_selector, format, options)
#
# File c:\DEV\NLO_Case\nlo_case\Lib\site-packages\pyarrow\dataset.py:422, in _ensure_single_source(path, filesystem)
#     420     paths_or_selector = [path]
#     421 else:
# --> 422     raise FileNotFoundError(path)
#     424 return filesystem, paths_or_selector
#
# FileNotFoundError: ./Case_1/bets_interview_completed.parquet
